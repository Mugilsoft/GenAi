# %%
import ollama

# %%
def get_completion(prompt, model="llama3.1"):
    response = ollama.chat(model=model, messages=[{"role": "user", "content": prompt}])
    return response['message']['content']

# %%
response = get_completion("What is the capital of France?")
print(response)
# Out:
# The capital of France is Paris.

# %%
response = get_completion("Take the letters in MugilSoft and reverse them")
print(response)
# Out:
# The reversed spelling of "MugilSoft" is "TfoSgilGUm".

# %%
response = get_completion("Take the letters in M-u-g-i-l-s-o-f-t and reverse them")
print(response)
# Out:
# The reversed letters are: f-t-o-f-s-i-l-g-u-m.

# %%
def get_completion_from_messages(messages, model="llama3.1"):
    response = ollama.chat(model=model, messages=messages)
    return response['message']['content']

# %%
messages = [
    {'role': 'system', 'content': "You are an assistant who responds in the style of Dr Seuss."},
    {'role': 'user', 'content': "Write me a very short poem about a happy carrot"}
]

response = get_completion_from_messages(messages)
print(response)
# Out:
# In the garden, oh so bright,
# Grew a carrot with pure delight!
# Its orange hue shone like the sun,
# This happy veggie had just begun!

# %%
# Length restriction example
messages = [
    {'role': 'system', 'content': 'All your responses must be one sentence long.'},
    {'role': 'user', 'content': 'Write me a story about a happy Apple'},
]
response = get_completion_from_messages(messages)
print(response)
# Out:
# In the lush orchard of Sunshine Farm, a particularly vibrant apple named Lola grew on the sunniest branch, her bright red skin glistening with dew and her leaves dancing happily in the breeze.

# %%
messages = [
    {'role': 'system', 'content': """You are an assistant who responds in the style of Dr Seuss.
    All your responses must be one sentence long."""},
    {'role': 'user', 'content': "Write me a story about a happy Apple"}
]
response = get_completion_from_messages(messages)
print(response)
# Out:
# In a sunny orchard, where the trees stood tall and bright, there grew a happy apple named Honey, who shone with delight!

# %%
def get_completion_and_token_count(messages, model="llama3.1"):
    response = ollama.chat(model=model, messages=messages)
    
    # Ollama does not return exact token counts, so we estimate
    formatted_prompt = "\n".join([msg["content"] for msg in messages])
    
    token_dict = {
        'prompt_tokens': len(formatted_prompt.split()),  # Approximate count
        'completion_tokens': len(response['message']['content'].split()),
        'total_tokens': len(formatted_prompt.split()) + len(response['message']['content'].split()),
    }

    return response['message']['content'], token_dict

# %%
messages = [
    {'role': 'system', 'content': "You are an assistant who responds in the style of Dr Seuss."},
    {'role': 'user', 'content': "Write me a very short poem about a happy Apple"}
]

response, token_dict = get_completion_and_token_count(messages)

print("Response:", response)
print("Token Usage:", token_dict)
# Out:
# Response: In the orchard, oh so bright,
# Grew a happy apple, shining with delight!
# It beamed and glowed, with a grin so wide,
# This merry fruit, danced with joy inside!
# Token Usage: {'prompt_tokens': 22, 'completion_tokens': 29, 'total_tokens': 51}
