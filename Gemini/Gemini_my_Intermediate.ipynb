# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyBW7jcqaGKcqpzFM8Zja8q3PoWvYnlpj-M")  # Replace with your actual Gemini API key

# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready!")

# Load the model
model = genai.GenerativeModel(model_name="gemini-1.5-flash")

# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = model.generate_content(user_input)

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  indian law assistant
# Your new assistant is ready!
#  i will apply insolvency petition so how apply
# Applying for an insolvency petition is a complex legal process that varies significantly depending on your location (country and even state/province) and the specific circumstances.  It's **crucial** to seek professional legal advice from a qualified insolvency practitioner or solicitor specializing in bankruptcy and insolvency law.  They can guide you through the specific requirements and procedures applicable to your situation.
#
# However, generally speaking, the process involves these steps:
#
# 1. **Gather Necessary Documentation:** This will include detailed financial records, such as balance sheets, profit and loss statements, tax returns, bank statements, and any other relevant documents showcasing your financial situation and the inability to pay debts.  The exact requirements vary by jurisdiction.
#
# 2. **Determine the Appropriate Insolvency Proceedings:**  The type of insolvency petition you file depends on whether you're an individual or a business, and the nature of your debts.  Common types include bankruptcy (for individuals), liquidation (for companies), and administration (for companies).  Your legal advisor will help you determine the best course of action.
#
# 3. **Prepare the Petition:**  This is a formal legal document that outlines your reasons for seeking insolvency and details your assets, liabilities, and creditors.  The petition must comply with strict legal requirements regarding formatting, content, and supporting evidence.  Errors can lead to delays or rejection.
#
# 4. **File the Petition:**  The petition is filed with the appropriate court or insolvency authority in your jurisdiction.  This usually involves paying a filing fee.
#
# 5. **Serve Notice on Creditors:**  After filing, you must formally notify your creditors of the petition.  The specific methods of notification are governed by law.
#
# 6. **Court Hearing:**  The court will review your petition and may schedule a hearing to assess its validity and determine the next steps.  This could involve a meeting of creditors.
#
# 7. **Post-Filing Procedures:**  Following a successful petition, there will be further procedures, including asset evaluation, debt distribution (if possible), and potential discharge from debts (for individuals).
#
# **Again, this is a general overview.  The specific steps and requirements vary dramatically by location and circumstances.  Do not attempt to navigate this process alone.**  The consequences of incorrect filings can be severe.  Consult with a qualified insolvency professional immediately. They can:
#
# * **Assess your eligibility:** Determine if you meet the requirements for filing an insolvency petition.
# * **Prepare the necessary documents:** Ensure your petition is compliant with all legal requirements.
# * **Represent you in court:** Advocate for your interests during the court proceedings.
# * **Advise you on your options:** Help you understand the implications of insolvency and explore alternatives.
#
#
# Ignoring professional advice in this matter could lead to significant legal and financial problems.  Seek help from a qualified expert as soon as possible.
#  i have bank collection agent harashments so how to avoid
# Dealing with harassment from bank collection agents requires a firm and strategic approach.  Here's how to avoid further harassment and protect your rights:
#
# **1. Document Everything:**
#
# * **Keep a detailed log:** Note down every contact—date, time, method (phone call, email, letter), agent's name (if possible), and a summary of the conversation. Include any abusive language or threats.
# * **Save all communication:** This includes emails, letters, text messages, and voicemails.
#
# **2. Understand Your Rights:**
#
# * **Fair Debt Collection Practices Act (FDCPA):**  In the US, the FDCPA protects you from abusive, deceptive, and unfair debt collection practices.  Familiarize yourself with this act.  Know that they cannot contact you before 8 am or after 9 pm, cannot harass you, cannot threaten you with actions they cannot legally take (like arrest), cannot contact your employer directly, etc.
# * **Your state's laws:**  Many states have their own laws regarding debt collection, which may offer additional protections.
#
# **3. Respond Officially, But Don't Engage in Arguments:**
#
# * **Validate the debt:**  Ask the collector to provide written verification of the debt, including the amount owed, the creditor's name, and proof of the debt.  This is a crucial step under the FDCPA.
# * **Communicate in writing:**  Whenever possible, communicate with the collector in writing (certified mail with return receipt requested is best). This creates a documented record of your communication.
# * **Remain calm and professional:**  Avoid arguing or getting emotional.  State your rights clearly and politely.
# * **Request they cease contact (in writing):** If they are violating the FDCPA, send a formal cease and desist letter demanding they stop all contact.
#
# **4.  Seek Legal Advice:**
#
# * **Contact a consumer protection agency:**  Inquire about resources and assistance available to you.
# * **Consult a lawyer specializing in debt collection:**  A lawyer can advise you on your rights and represent you in disputes with the collector.  They can help you navigate the legal process and potentially sue the collection agency for violations.
#
# **5.  Consider Debt Management Options:**
#
# * **Negotiate a payment plan:** If you can afford to pay some portion of the debt, try negotiating a payment plan with the creditor or the collector.
# * **Debt consolidation:** Consider consolidating your debt to simplify payments and potentially lower interest rates.
# * **Credit counseling:**  A credit counselor can help you create a budget and develop a debt management plan.
#
# **6.  Report Harassment:**
#
# * **File a complaint with the Consumer Financial Protection Bureau (CFPB):**  In the US, the CFPB is a federal agency that regulates financial institutions, including debt collectors.
# * **File a complaint with your state's attorney general:** Many states have consumer protection agencies that handle complaints about debt collection harassment.
#
#
# **Important Note:**  Ignoring the issue will not make it go away.  Proactive and informed action is crucial in protecting yourself from harassment and managing your debt effectively.  Don't be intimidated; you have rights.
