# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyBW7jcqaGKcqpzFM8Zja8q3PoWvYnlpj-M")  # Replace with your actual Gemini API key

# Create a model instance
model = genai.GenerativeModel(model_name="gemini-1.5-flash")

# Generate response
response = model.generate_content("Give me 3 ideas for apps I could build with OpenAI APIs")

# Print output
print(response.text)
# Out:
# Here are 3 app ideas using OpenAI APIs, targeting different user needs and skill levels:
#
# 1. **Personalized Children's Storybook Generator:**
#
# * **Concept:** An app that generates unique, illustrated children's stories based on user input.  Parents or educators could input a character name, a setting (e.g., "a magical forest"), and a theme (e.g., "friendship," "overcoming fear"), and the app would generate a story with accompanying illustrations.
# * **OpenAI APIs Used:**  `GPT-3` or `GPT-4` for story generation (narrative structure, character dialogue, plot points), `DALL-E 2` for image generation (illustrations based on the story's descriptions).
# * **Monetization:** Freemium model (limited stories/illustrations for free, subscription for unlimited access).  Potential partnerships with illustrators for higher quality illustrations.
#
# 2. **AI-Powered Content Repurposing Tool:**
#
# * **Concept:** An app that takes a long-form piece of content (blog post, article, script) and automatically repurposes it into various formats – shorter social media posts, tweet threads, email newsletters, or even different languages.
# * **OpenAI APIs Used:** `GPT-3` or `GPT-4` for text summarization, translation, and stylistic adaptation (e.g., changing tone from formal to informal).
# * **Monetization:** Subscription based on usage (number of words processed, number of outputs generated).  Target audience: bloggers, marketers, content creators.
#
# 3. **Creative Writing Assistant with Style Imitation:**
#
# * **Concept:** An app that helps writers overcome writer's block and experiment with different writing styles. Users input a short prompt or a paragraph, and the app generates continuations, offering various options with different tones and styles.  It could even allow users to specify a particular author or style to emulate.
# * **OpenAI APIs Used:** `GPT-3` or `GPT-4` for text generation and style transfer.
# * **Monetization:** Freemium model (limited number of generations for free, subscription for unlimited access and advanced features like style comparison and analysis).  Target audience: novelists, scriptwriters, creative writers.
#
#
# These are just starting points; each idea could be expanded and refined further based on market research and user feedback.  Consider the technical challenges and the specific API limitations when planning your app development.
